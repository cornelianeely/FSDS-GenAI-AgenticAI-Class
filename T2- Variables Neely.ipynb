# %%
first_name = 'Cornelia'

# %%
last_name = 'Neely'

# %%
country = 'USA'

# %%
city = 'Los Angeles'

# %%
age = 42

# %%
is_married = False

# %%
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']

# %%
person_info = {
    'firstname' : 'Cornelia',
    'lastname' : 'Neely',
    'country' : 'USA',
    'city' : 'Los Angeles'}

# %%
print('First name:', first_name)
# Out:
# First name: Cornelia

# %%
print('First name length:', len(first_name))
# Out:
# First name length: 8

# %%
print('Last name:', last_name)
# Out:
# Last name: Neely

# %%
print('Last name length:', len(last_name))
# Out:
# Last name length: 5

# %%
print('Country: ', country)
# Out:
# Country:  USA

# %%
print('City: ', city)
# Out:
# City:  Los Angeles

# %%
print('Age: ', age)
# Out:
# Age:  42

# %%
print('Married: ', is_married)
# Out:
# Married:  False

# %%
print('Person information: ', person_info)
# Out:
# Person information:  {'firstname': 'Cornelia', 'lastname': 'Neely', 'country': 'USA', 'city': 'Los Angeles'}

# %%
first_name, last_name, country, age, is_married = 'Cornelia', 'Neely', 'USA', '42', False

# %%
print(first_name, last_name, country, age, is_married)
# Out:
# Cornelia Neely USA 42 False

# %%
print('First name:', first_name
# Out:
#   Cell In[21], line 1
#     print('First name:', first_name
#                                    ^
# _IncompleteInputError: incomplete input

# %%
print('First name:', first_name)
# Out:
# First name: Cornelia

# %%
print('Last name:', last_name)
# Out:
# Last name: Neely

# %%
print('Country:', country)
# Out:
# Country: USA

# %%
print('Age:', age)
# Out:
# Age: 42

# %%
print('Married:', is_married)
# Out:
# Married: False
