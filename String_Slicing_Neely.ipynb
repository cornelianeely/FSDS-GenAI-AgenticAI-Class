# %% [markdown]
# <a href="https://colab.research.google.com/github/cornelianeely/FSDS-GenAI-AgenticAI-Class/blob/main/String_Slicing_Neely.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is the first comment
spam = 1 # and this is the second comment
         #...and now a third
text = " # This is not a comment because it's inside quotes."

# %% [markdown]
# # Python as a Calculator

# %%
# Numbers

# %%
2 + 2
# Out:
# 4

# %%
 50 - 5 * 6
# Out:
# 20

# %%
(50 - 5 *6) / 4
# Out:
# 5.0

# %%
8 / 5
# Out:
# 1.6

# %%
17 / 3 # classic division returns a float
# Out:
# 5.666666666666667

# %%
17 // 3 # floor division discards the fractional part
# Out:
# 5

# %%
17 % 3 # the % operator returs the remainder of the division
# Out:
# 2

# %%
5 * 3 + 2 # floored quotient * divisor + remainder
# Out:
# 17

# %%
# The ** operator is used to calculate powers

# %%
5 ** 2 # 5 squared
# Out:
# 25

# %%
2 ** 7 # 2 to the power of 7
# Out:
# 128

# %%
# The equal sign (=) is used to assign value to a variable

# %%
width = 20
height = 5 * 9
width * height
# Out:
# 900

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 n
#
# NameError: name 'n' is not defined

# %%
4 * 3.75 -1
# Out:
# 14.0

# %%
tax = 12.5 / 100
price = 100.50
price * tax
# Out:
# 12.5625

# %%
price + _
# Out:
# 113.0625

# %%
round(_, 2)
# Out:
# 113.06

# %%
# text

# %%
'spam eggs' # single quotes
# Out:
# 'spam eggs'

# %%
"Paris rabbit got your back :)? Yay!" # double quotes
# Out:
# 'Paris rabbit got your back :)? Yay!'

# %%
'1975' #digits and numerals eclosed in quores are also string
# Out:
# '1975'

# %%
'doesn\'t' #use the \' to escape the single quote
# Out:
# "doesn't"

# %%
"doesn't" # or use double quotes instead
# Out:
# "doesn't"

# %%
'"Yes," they said.'
# Out:
# '"Yes," they said.'

# %%
'"Isn\'t," they said.'
# Out:
# '"Isn\'t," they said.'

# %%
s = 'First line. \nSecond line.' # \n means newline
s #without print(), special characters are inclded in the string
# Out:
# 'First line. \nSecond line.'

# %%
print(s) # with print(), special characters are iterpreted, so \n produces new line
# Out:
# First line.
# Second line.

# %%
print('C:\some\name') # here \n means newline!
# Out:
# C:\some
# ame
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_198/2526073677.py:1: SyntaxWarning: invalid escape sequence '\s'
#   print('C:\some\name') # here \n means newline!

# %%
print(r'C:\some\name') # note the r before the quote
# Out:
# C:\some\name

# %%
print("""\
... Usage: thingy [Options]
...     -h              Display this usage message
...     -H hostname     Hostname to connect to
...""")
# Out:
# Usage: thingy [Options]
#     -h              Display this usage message
#     -H hostname     Hostname to connect to
# ...

# %%
# 3 times 'un', followed by 'ium'

# %%
3 * 'un' + 'ium'
# Out:
# 'unununium'

# %%
'Py' 'thon'
# Out:
# 'Python'

# %%
text = ('Put several strings within parentheses '
        'to have them joined together.')
text
# Out:
# 'Put several strings within parentheses to have them joined together.'

# %%
prefix = 'Py'

# %%
prefix 'thon' # can't concatenate a variable and string literal
File "<stdin>", line 1
  prefix 'thon'
# Out:
#   File "/tmp/ipykernel_198/106448848.py", line 1
#     prefix 'thon' # can't concatenate a variable and string literal
#            ^
# SyntaxError: invalid syntax

# %%
prefix + 'thon'
# Out:
# 'Python'

# %%
('un' * 3) 'ium'
File "<stdin>", line 1
  ('un' * 3) 'ium'
# Out:
#   File "/tmp/ipykernel_198/1661911191.py", line 1
#     ('un' * 3) 'ium'
#                ^
# SyntaxError: invalid syntax

# %%
prefix + 'thon'
# Out:
# 'Python'

# %%
word = 'Python'

# %%
word[0] # character is position 0
# Out:
# 'P'

# %%
word[5] # character in position 5
# Out:
# 'n'

# %%
word[-1] # last character
# Out:
# 'n'

# %%
word[-2] # second to last character
# Out:
# 'o'

# %%
word[-6]
# Out:
# 'P'

# %%
word[0:2] # characters from position 0 (included) to 2 (excluded)
# Out:
# 'Py'

# %%
word[2:5] #characters from position 2(included) to 5(excluded)
# Out:
# 'tho'

# %%
word[:2] # characters from the beginning to position 2 (excluded)
# Out:
# 'Py'

# %%
word[4:] # characters from position 4 (included) to the end
# Out:
# 'on'

# %%
word[-2:] # characters from the second to last (included) to the end
# Out:
# 'on'

# %%
word[:2] + word[2:]
# Out:
# 'Python'

# %%
word[:4] + word[4:]
# Out:
# 'Python'

# %%
word[42]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_198/1308383204.py in <cell line: 0>()
# ----> 1 word[42]
#
# IndexError: string index out of range

# %%
word[4:42]
# Out:
# 'on'

# %%
word[42:]
# Out:
# ''

# %%
# python strings cannot be changed- they are immutable. Therefore, assigning to an indexed position in the string results in an error.

# %%
word[0] = 'J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_198/2664689217.py in <cell line: 0>()
# ----> 1 word[0] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %%
word[2:] = 'py'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_198/1560658847.py in <cell line: 0>()
# ----> 1 word[2:] = 'py'
#
# TypeError: 'str' object does not support item assignment

# %%
'J' + word[1:]
# Out:
# 'Jython'

# %%
word[:2] + 'py'
# Out:
# 'Pypy'

# %%
s = 'supercalifragilisticexpialidocious'

# %%
len(s)
# Out:
# 34
