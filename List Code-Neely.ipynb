# %%
txt = " abc def ghi "
txt.lstrip()
# Out:
# 'abc def ghi '

# %%
txt = " abc def ghi "
txt.strip()
# Out:
# 'abc def ghi'

# %% [markdown]
# # Using Escape Character

# %%
# Using double quotes in the string is not allowed
mystr = "My favorite TV series is "Game of Thrones""
# Out:
#   Cell In[12], line 2
#     mystr = "My favorite TV series is "Game of Thrones""
#                                        ^
# SyntaxError: invalid syntax

# %%
# Using escape character to allow illegal characters
mystr = "My favorite series is \"Game of Thrones\""
print(mystr)

# %% [markdown]
# # List

# %% [markdown]
# # List Creation

# %%
list1 = [] # Empty List

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10,30,60] # list of integer numbers

# %%
list3 = [10.77, 30.66, 60.89] # list of float numbers

# %%
list4 = ['one', 'two', "three"] #List of strings

# %%
list5 = ['Asif', 25, [50,100], [150,90]] #Nested List

# %%
list6 = [100, 'Asif', 17.765] # list of mixed data types

# %%
list7 = ['Asif', 25, [50,100], [150,90], {'John', 'David'}]

# %%
len(list6)
# Out:
# 3

# %%
list2[0] # retrieve first element of the list
# Out:
# 10

# %%
list4[0] # retrieve first element of the list
# Out:
# 'one'

# %%
list4[0][0] # nested indexing- access the first character of the first list element
# Out:
# 'o'

# %%
list4[-1] #last item of the list
# Out:
# 'three'

# %%
list5[-1] # last item of the list
# Out:
# [150, 90]

# %% [markdown]
# # List Slicing

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist[0:3] #return all items from 0 to 3rd index location excluding third index
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5] #list all itesm from 2nd to 5th index location excluding 5th index
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3] #return first three items
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2] # return first two items
# Out:
# ['one', 'two']

# %%
mylist[-3:] # return last three items
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:] #return last two items
# Out:
# ['seven', 'eight']

# %%
mylist[-1:] # return last item of the list
# Out:
# ['eight']

# %%
mylist[:] #return whole list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # Add | Remove | Change Items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine') #add an item to the end of the list
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.insert(9,'ten') #add item at index location 9
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.insert(1, 'ONE') #add item at index location 1
mylist
# Out:
# ['one',
#  'ONE',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten']

# %%
mylist.remove('ONE') # removes item "ONE"
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.pop() #removes the last item of the list
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.pop(8) #removes item at index location 8
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
del mylist[7] #removes item at index location 7
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
# Change value of the string
mylist[0] = 1
mylist[1] = 2
mylist[2] = 3
mylist
# Out:
# [1, 2, 3, 'four', 'five', 'six', 'seven']

# %%
mylist.clear() #Empty List/ Delete all items in the list
mylist
# Out:
# []

# %%
del mylist #deletes the whole list
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 2
#       1 del mylist #deletes the whole list
# ----> 2 mylist
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# # Copy List

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 = mylist #create a new reference "mylist 1"

# %%
id(mylist), id(mylist1) #the address of both mylist and mylist1 will be same
# Out:
# (2772499993664, 2772499993664)

# %%
mylist2 = mylist.copy() #creates a copy of the list

# %%
id(mylist2) #address will be different
# Out:
# 2772500289664

# %%
mylist[0] = 1

# %%
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 #mylist1 is impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist2 #copy of list wont be impacted due to changes made on the original list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# # Join Lists

# %%
list1 = ['one', 'two', 'three', 'four']
list2 = ['five', 'six', 'seven', 'eight']

# %%
list3 = list1 + list2 #join two lists by '+' operator
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2) #append list2 with list1
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # List memebership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1 #check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1
# Out:
# False

# %%
if 'three' in list1:
    print('Three is present in the list')
else:
    print('Three is not present in the list')
# Out:
# Three is present in the list

# %%
if 'eleven' in list1:
    print('Eleven is present in the list')
else:
    print('Eleven is not present in the list')
# Out:
# Eleven is not present in the list

# %% [markdown]
# # Reverse and Sort List

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse() #reverses the list

# %%
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1 = list1[::-1] #reverses the list
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort() #sort the list in ascending order
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort(reverse=True) #sort list in descending order
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88,65,33,21,11,98]
sorted(mylist4) #returns a new sorted list and doesnt change original list
# Out:
# [11, 21, 33, 65, 88, 98]

# %%
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]

# %% [markdown]
# # Loop through a list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
for i in list1:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(list1): # enumerate provides index number with value
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %%
list10 = ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count('one') # number of times item "one" occured in the list
# Out:
# 3

# %%
list10.count('two') # number of times item "two" occured in the list
# Out:
# 2

# %%
list10.count('four') # number of times item "four" occured in the list
# Out:
# 1

# %% [markdown]
# # All / Any

# %% [raw]
# The all() method returns:
# -True if all elements in a list are true
# -False if any elements in a list are false
#
# The any() function returns True if any element in the list is true. If not any() returns false

# %%
L1 = [1,2,3,4,0]

# %%
all(L1) # will return false as one value is false (Value 0)
# Out:
# False

# %%
any(L1) #will return true as we have items in the list with true value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]

# %%
all(L2) # returns false as one value is false
# Out:
# False

# %%
any(L2) #returns true as we have items in the list with true value
# Out:
# True

# %%
L3 = [1,2,3,True]

# %%
all(L3) # will return true as all items in the list are true
# Out:
# True
