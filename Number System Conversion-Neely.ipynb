# %% [markdown]
# Number System Conversion

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
int(0b11110)
# Out:
# 30

# %%
0o31
# Out:
# 25

# %%
0b11001
# Out:
# 25

# %%
int(0b11001)
# Out:
# 25

# %%
bin(7)
# Out:
# '0b111'

# %%
oct(25)
# Out:
# '0o31'

# %%
0o31
# Out:
# 25

# %%
int(0o31)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
0x19
# Out:
# 25

# %%
hex(16)
# Out:
# '0x10'

# %%
0xa
# Out:
# 10

# %%
0xb
# Out:
# 11

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(25)
# Out:
# '0x19'

# %%
0x19
# Out:
# 25
