# %% [markdown]
# <a href="https://colab.research.google.com/github/cornelianeely/FSDS-GenAI-AgenticAI-Class/blob/main/Welcome_to_Colab_Neely.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Getting Started

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Python Datatypes
# *   Int
# *   float
# *   bool
# *   complex
# *   string

# %%
4 # int without variable
# Out:
# 4

# %%
10
# Out:
# 10

# %%
4 +10
# Out:
# 14

# %%
_
# Out:
# 14

# %%
_ + 5
# Out:
# 19

# %%
_ + 2
# Out:
# 21

# %%
_ - 3
# Out:
# 18

# %%
i = 5 # int with variable
i
# Out:
# 5

# %%
id(i)
# Out:
# 11654504

# %%
type(i)
# Out:
# int

# %% [markdown]
# float

# %%
# float

# %%
petrol_price= 110.45
petrol_price
# Out:
# 110.45

# %%
gold_price = 11000.56
gold_price
# Out:
# 11000.56

# %%
f2 = 2e0
f2
# Out:
# 2.0

# %%
type(f2)
# Out:
# float

# %%
f3 = 2.5e2
f3
# Out:
# 250.0

# %%
f4 = 3.4E3
f4
# Out:
# 3400.0

# %% [markdown]
# Boolean (BOOL)

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
None

# %%
print(True + True)
print(True + False)
print(True -True)
print(False - False)
# Out:
# 2
# 1
# 0
# 0

# %%
10 / 2 # float division
# Out:
# 5.0

# %%
10 // 2
# Out:
# 5

# %%
False / True
# Out:
# 0.0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-622/2917913318.py in <cell line: 0>()
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Complex
# Format of the complex-- a + bj

# %%
c = 10 +20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
d = 20 +30j
d
# Out:
# (20+30j)

# %%
print(c)
print(d)
# Out:
# (10+20j)
# (20+30j)

# %%
print(type(i))
# Out:
# <class 'int'>

# %%
type(f) #f was never defined in previous work
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-622/1143490003.py in <cell line: 0>()
# ----> 1 type(f)
#
# NameError: name 'f' is not defined

# %%
type(f2)
# Out:
# float

# %%
type(c)
# Out:
# complex

# %%
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %% [markdown]
# String

# %%
welcome
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-622/1243561387.py in <cell line: 0>()
# ----> 1 welcome
#
# NameError: name 'welcome' is not defined

# %%
welcome = 7
welcome
# Out:
# 7

# %%
nit = 7
nit
# Out:
# 7

# %%
# python string must be assigned ''/""/''' '''

# %%
welcome_message = "welcome to nit 7pm prakash senapati sir batch"
# Out:
#   File "/tmp/ipython-input-622/1322443245.py", line 1
#     welcome to nit 7pm prakash senapati sir batch
#                    ^
# SyntaxError: invalid decimal literal

# %%
'Welcome to nit 7pm prakash senapati sir batch'
# Out:
# 'Welcome to nit 7pm prakash senapati sir batch'

# %%
"Welcome to nit 7pm prakash senapati sir batch"
# Out:
# 'Welcome to nit 7pm prakash senapati sir batch'

# %%
'''Welcome to nit 7pm prakash senapati sir batch'''
# Out:
# 'Welcome to nit 7pm prakash senapati sir batch'

# %%
'''Welcome
to nit
7pm prakash
senapati sir
batch'''
# Out:
# 'Welcome\nto nit\n7pm prakash\nsenapati sir\nbatch'
