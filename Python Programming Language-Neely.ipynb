# %% [markdown]
# # Python Basic and Python operator

# %%
1+1 # ADDITION
# Out:
# 2

# %%
2-1
# Out:
# 1

# %%
3*4 # DIVISION
# Out:
# 12

# %%
8 / 4
# Out:
# 2.0

# %%
8 / 5 # float division
# Out:
# 1.6

# %%
8/4 ##float division
# Out:
# 2.0

# %%
8//4 #integer division
# Out:
# 2

# %%
8+9-7
# Out:
# 10

# %%
8+8- #syntax error
# Out:
#   Cell In[9], line 1
#     8+8- #syntax error
#          ^
# SyntaxError: invalid syntax

# %%
5+5*5
# Out:
# 30

# %%
(5+5)*5 #BODMAS (Bracket||Order of operations||Division||Multiplication||Addition||Subtraction)
# Out:
# 50

# %%
2*2*2*2*2 #exponentiation
# Out:
# 32

# %%
2*5
# Out:
# 10

# %%
2**5
# Out:
# 32

# %%
15/3
# Out:
# 5.0

# %%
10//3
# Out:
# 3

# %%
15%2 #MODULUS (remainder of the division)
# Out:
# 1

# %%
10%2
# Out:
# 0

# %%
15 %% 2 #syntax error
# Out:
#   Cell In[19], line 1
#     15 %% 2 #syntax error
#         ^
# SyntaxError: invalid syntax

# %%
3+'nit'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 3+'nit'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a,b,c,d,e= 15,7.8, 'nit', 8+9j, True


print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 15
# 7.8
# nit
# (8+9j)
# True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %%
type(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 type(c)
#
# NameError: name 'c' is not defined

# %%
'Naresh IT'
# Out:
# 'Naresh IT'

# %%
print('Max it')
# Out:
# Max it

# %%
"max it technology"
# Out:
# 'max it technology'

# %%
s1= 'max it technology'
s1
# Out:
# 'max it technology'

# %%
a=2
b=3
a+b
# Out:
# 5

# %%
c=a+b
c
# Out:
# 5

# %%
a=3
b= 'hi'
type(b)
# Out:
# str

# %%
print('max it's"Technology"') # \ has some special meaning to ignore the error
# Out:
#   Cell In[31], line 1
#     print('max it's"Technology"') # \ has some special meaning to ignore the error
#                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('max it\'s"Technology"')
# Out:
# max it's"Technology"

# %%
print('max it', 'Technology')
# Out:
# max it Technology

# %%
print("max it', 'Technology")
# Out:
# max it', 'Technology

# %%
#print the nit 2 times
'nit' + ' nit'
# Out:
# 'nit nit'

# %%
'nit' ' nit'
# Out:
# 'nit nit'

# %%
5 * 'nit'
# Out:
# 'nitnitnitnitnit'

# %%
5 * ' nit' # space between words
# Out:
# ' nit nit nit nit nit'

# %%
print('c:\nit') #\n--new line
# Out:
# c:
# it

# %%
print(r'c:\nit') #raw string--ignore special characters
# Out:
# c:\nit

# %% [markdown]
# Variable || Identifier || Object

# %%
2
# Out:
# 2

# %%
x = 2
x
# Out:
# 2

# %%
x + 3
# Out:
# 5

# %%
y = 3
y
# Out:
# 3

# %%
x + y
# Out:
# 5

# %%
x= 9
x
# Out:
# 9

# %%
x + y
# Out:
# 12

# %%
x + 10
# Out:
# 19

# %%
_ + y #_ is the last output
# Out:
# 22

# %%
_ + y
# Out:
# 25

# %%
_ + y
# Out:
# 28

# %%
_ + y
# Out:
# 31

# %%
y
# Out:
# 3

# %%
_ + y
# Out:
# 6

# %%
_ + y
# Out:
# 9

# %%
_ + y
# Out:
# 12

# %% [raw]
# String Variable

# %%
name= 'mit'

# %%
name
# Out:
# 'mit'

# %%
name + 'technology'
# Out:
# 'mittechnology'

# %%
name + ' technology'
# Out:
# 'mit technology'

# %%
name 'technology'
# Out:
#   Cell In[61], line 1
#     name 'technology'
#          ^
# SyntaxError: invalid syntax

# %%
name
# Out:
# 'mit'

# %%
len(name)
# Out:
# 3

# %%
name[0]
# Out:
# 'm'

# %%
name[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 name[5]
#
# IndexError: string index out of range

# %%
name[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 name[7]
#
# IndexError: string index out of range

# %%
name[-1]
# Out:
# 't'

# %%
name[-2]
# Out:
# 'i'

# %%
name[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 name[-6]
#
# IndexError: string index out of range

# %% [markdown]
# Slicing

# %%
name
# Out:
# 'mit'

# %%
name[0:1]
# Out:
# 'm'

# %%
name[0:2]
# Out:
# 'mi'

# %%
name[1:]
# Out:
# 'it'

# %%
name[:4]
# Out:
# 'mit'

# %%
name[3:9]
# Out:
# ''

# %%
name
# Out:
# 'mit'

# %%
name1 = 'fine' #change the string fine to dine
name1
# Out:
# 'fine'

# %%
name1[0:1]
# Out:
# 'f'

# %%
name1[0:1]  = 'd' # i want to chage 1st character of fine to dine
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 name1[0:1]  = 'd' # i want to chage 1st character of fine to dine
#
# TypeError: 'str' object does not support item assignment

# %%
name1[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 name1[0] = 'd'
#
# TypeError: 'str' object does not support item assignment

# %%
name1
# Out:
# 'fine'

# %%
name1[1:]
# Out:
# 'ine'

# %%
'd' + name1[1:] #i want to change fine to dine by slicing and concatenation
# Out:
# 'dine'

# %%
num1.insert(2, 'nit') #insert the values as per index values. i.e. 2nd index we are assigning nit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 num1.insert(2, 'nit') #insert the values as per index values. i.e. 2nd index we are assigning nit
#
# NameError: name 'num1' is not defined

# %% [markdown]
# Introduction to ID()

# %%
#variable address
num = 5
id(num)
# Out:
# 140727693956136

# %%
name = 'nit'
id(name) #address will be diferent for both
# Out:
# 2335988735824

# %%
a = 10
id(a)
# Out:
# 140727693956296

# %%
b = a #that's wh python is more memory efficient than other programming languages. it will not create a new address for b, it will point to the same address as a because both are having same value. if we change the value of a then it will create a new address for a and b will still point to the old address.

# %%
id(b)
# Out:
# 140727693956296

# %%
id(10)
# Out:
# 140727693956296

# %%
k = 10
id(k)
# Out:
# 140727693956296

# %%
a = 20 #as we change the value of a then address will change
id(a)
# Out:
# 140727693956616

# %%
id(b)
# Out:
# 140727693956296

# %% [markdown]
# whatever the variable we assigned the memory and we not assigned anywhere, than we can use as garbage collection.|| Variable- we can change the values|| Constant- we cannot change the value- can we make variable as a constant?- In Python you cannont make a variable a constant

# %%
PI= 3.14 # in math, this is always constant but python we can change
PI
# Out:
# 3.14

# %%
PI = 3.15
PI
# Out:
# 3.15

# %%
type(PI)
# Out:
# float

# %% [markdown]
# Operator
#
# 1- Arithmetic Operations: (+, -, *, /, %, %%, **, ^)
# 2- Assignment Operator: (=, +=, *=, -=, /=, //=, )
# 3- Relational Operator: (=, ==, <, >, <=, >=, !=)
# 4- Logical Operator: (AND, OR, NOT)
# 5- Unary Operator: Unary means 1|| binary means 2; here we are applying unary  minus operator on the operand n; the value of m becomes -7, which indicates it as a negative value

# %%
x1, y1 = 10, 5

# %%
#x1 ^ y1

# %%
x1 + y1
# Out:
# 15

# %%
x1 -y1
# Out:
# 5

# %%
x1 * y1
# Out:
# 50

# %%
x1 / y1
# Out:
# 2.0

# %%
x1 // y1
# Out:
# 2

# %%
x1 % y1
# Out:
# 0

# %%
x1 ** y1
# Out:
# 100000

# %%
x2 = 3
y2 = 2
x2 ** y2
# Out:
# 9

# %% [markdown]
# Assignment Operators

# %%
x = 2

# %%
x = x + 2 #if you want ot increment the value of x by 2.

# %%
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x += 2
x
# Out:
# 8

# %%
x *= 2

# %%
x
# Out:
# 16

# %%
x -= 2

# %%
x
# Out:
# 14

# %%
x /= 2
x
# Out:
# 7.0

# %%
x //=2
x
# Out:
# 3.0

# %%
a, b = 5,6 #you can assign variables in one line as well

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %% [markdown]
# Relational Operators

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
# a - b # we cannot use = operator  that means it is assigning

# %%
a ==b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
#hear if I change b=6
b = 5

# %%
a == b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# False

# %%
b = 7

# %%
a != b
# Out:
# True

# %% [markdown]
# Unary Operator

# %%
n = 7 # negation
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
n
# Out:
# 7

# %%
-n
# Out:
# -7

# %% [markdown]
# Logical Operator

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a <8 and b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
a > 8 or b < 2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x # you can reverse the operation
# Out:
# True
