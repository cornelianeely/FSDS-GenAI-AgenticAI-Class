# %%
print(3 + 2)
# Out:
# 5

# %%
print(3 - 2)
# Out:
# 1

# %%
print(3 * 2)
# Out:
# 6

# %%
print(3 ** 2)
# Out:
# 9

# %%
print(3 % 2)
# Out:
# 1

# %%
print(3 // 2)
# Out:
# 1

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type(3.14))
# Out:
# <class 'float'>

# %%
print(1 +3j))
# Out:
#   Cell In[9], line 1
#     print(1 +3j))
#                 ^
# SyntaxError: unmatched ')'

# %%
print(type(1 + 3j))
# Out:
# <class 'complex'>

# %%
print(type('cornelianeely'))
# Out:
# <class 'str'>

# %%
print(type([1, 2, 3]))
# Out:
# <class 'list'>

# %%
print(type({'name' : 'neely'}))
# Out:
# <class 'dict'>

# %%
print(type({9.8, 3.14, 2.7}))
# Out:
# <class 'set'>

# %%
print(type((9.8, 3.14, 2.7)))
# Out:
# <class 'tuple'>

# %%
print(type(3 == 3))
# Out:
# <class 'bool'>

# %%
print(type(3 >= 3))
# Out:
# <class 'bool'>
