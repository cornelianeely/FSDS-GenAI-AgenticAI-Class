# %% [markdown]
# # python indexing & slicing

# %%
s1 = 'welcometeam'
s1
# Out:
# 'welcometeam'

# %%
type(s1)
# Out:
# str

# %%
len(s1)
# Out:
# 11

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[1] # forward index
# Out:
# 'e'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[-1]
# Out:
# 'm'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[:]
# Out:
# 'welcometeam'

# %%
s1[7:11]
# Out:
# 'team'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[7:]
# Out:
# 'team'

# %%
s1[:]
# Out:
# 'welcometeam'

# %%
s1[2:10]
# Out:
# 'lcometea'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[:10]
# Out:
# 'welcometea'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[4:]
# Out:
# 'ometeam'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[12:]
# Out:
# ''

# %%
s1[13]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s1[13]
#
# IndexError: string index out of range

# %%
s1[:13]
# Out:
# 'welcometeam'

# %% [raw]
# -s1[left:right]
# -s1[left:right:step]

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[:15]
# Out:
# 'welcometeam'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[1:8:2]
# Out:
# 'ecmt'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[::3]
# Out:
# 'wcea'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[-9:-1:3]
# Out:
# 'lme'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[::-1]
# Out:
# 'maetemoclew'

# %%
s1
# Out:
# 'welcometeam'

# %%
s1[::-2]
# Out:
# 'meeolw'

# %% [markdown]
# # 25th NUMBER SYSTEM

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
25
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(0)
# Out:
# '0x0'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(11)
# Out:
# '0xb'

# %%
hex(12)
# Out:
# '0xc'

# %%
hex(13)
# Out:
# '0xd'

# %%
hex(14)
# Out:
# '0xe'

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %% [markdown]
# # BITWISE OPERATOR

# %%
# complement  
~11
# Out:
# -12

# %%
~34
# Out:
# -35

# %%
~23
# Out:
# -24

# %% [markdown]
# # and &

# %%
12 & 13

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(13)
# Out:
# '0b1101'

# %%
12 & 13 #bitwise and
# Out:
# 12

# %% [markdown]
# # bitwise or

# %%
12 | 13 #bitwise or
# Out:
# 13

# %% [markdown]
# # xor ^

# %%
12 ^ 13
# Out:
# 1

# %% [markdown]
# # left shift <<

# %%
12 << 1
# Out:
# 24

# %%
12 << 2
# Out:
# 48

# %% [markdown]
# # right shift >>

# %%
12 >> 2
# Out:
# 3

# %%
12 >> 3
# Out:
# 1

# %%
15 >> 2
# Out:
# 3

# %% [markdown]
# # Math Modules and Input

# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
pi = 4.17
pi
# Out:
# 4.17

# %%
math.floor(3.23)
# Out:
# 3

# %%
math.ceil(3.23)
# Out:
# 4

# %%
math.pow(3,2)
# Out:
# 9.0

# %%
m.pow(3,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 m.pow(3,2)
#
# NameError: name 'm' is not defined

# %%
import math as n
n.pow(3,2)
# Out:
# 9.0

# %%
import math as m
print(m.pow(3,2))
print(m.floor(3.2))
print(m.ceil(3.2))
# Out:
# 9.0
# 3
# 4

# %%
from math import sqrt, pow, floor, ceil # math has many functions if you want to import specific functions then use import
print(pow(2,3))
print(sqrt(10))
print(floor(2.3))
print(ceil(2.3))
# Out:
# 8.0
# 3.1622776601683795
# 2
# 3

# %%
from math import *
print(pow(2,3))
print(sqrt(10))
print(floor(2.3))
print(ceil(2.3))
# Out:
# 8.0
# 3.1622776601683795
# 2
# 3

# %% [markdown]
# # Input ()

# %%
x = input()
x
# Out:
#  hello welcome team
# 'hello welcome team'

# %%
x1 = input()
y1 = input()

z = x1 + y1
print(z)
# Out:
#  3
#  4
# 34

# %%
type(y1)
# Out:
# str

# %%
x = int(input())
y = int(input())
z = x + y
print(z)
# Out:
#  5
#  4
# 9

# %%
type(z)
# Out:
# int

# %%
x1 = int(input('Enter the 1st number'))
y1 = int(input('Enter the 2nd number'))
z1 = x1 + y1
print(z1)
# Out:
# Enter the 1st number 10
# Enter the 2nd number 12
# 22

# %%
x1 = input('user_name')
y1 = input('password')
z1 = x1 + y1
print(z1)
# Out:
# user_name hello
# password 1234
# hello1234

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string hello
# hello

# %%
print(st[2])
# Out:
# l

# %%
st = input('enter a string')[0]
print(st)
# Out:
# enter a string NareshIT
# N

# %%
st = input('enter a string')[3:]
print(st)
# Out:
# enter a string 123456789
# 456789

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string 12+10-2
# 12+10-2

# %%
st = int(input('enter a string'))
print(st)
# Out:
# enter a string 12+10-2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 st = int(input('enter a string'))
#       2 print(st)
#
# ValueError: invalid literal for int() with base 10: '12+10-2'

# %%
result = eval(input('enter an expression'))
print(result)
# Out:
# enter an expression 12+10-2
# 20
