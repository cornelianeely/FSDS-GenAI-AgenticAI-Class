# %% [markdown]
# TYPE CASTING

# %%
int(230.34) # float to int
# Out:
# 230

# %%
int(230.34, 110.23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 int(230.34, 110.23)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True) #bool to int
# Out:
# 1

# %%
int(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(true)
#
# NameError: name 'true' is not defined

# %%
int(False)
# Out:
# 0

# %%
int(1 + 2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int(1 + 2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# Other datatypes to float type conversion->

# %%
float(23)
# Out:
# 23.0

# %%
float(True)
# Out:
# 1.0

# %%
float(1 + 2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 float(1 + 2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('20')
# Out:
# 20.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# ---Other datatypes to float type conversion--->

# %%
complex(10) #int to complex
# Out:
# (10+0j)

# %%
complex (10,20) # 2 argument int to complex
# Out:
# (10+20j)

# %%
complex (10, 20, 30) # 3 argument int to complex---can not do.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 complex (10, 20, 30) # 3 argument int to complex---can not do.
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex()
# Out:
# 0j

# %%
p, q = 20, 20

# %%
print(p)
print(q)
# Out:
# 20
# 20

# %%
print(id(p))
print(id(q))
# Out:
# 140727693956616
# 140727693956616

# %%
complex(10.3) #float to complex
# Out:
# (10.3+0j)

# %%
complex(10.3, 23) #2 argument float to complex
# Out:
# (10.3+23j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex (False, False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('20', '10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 complex('20', '10')
#
# TypeError: complex() can't take second arg if first is a string
